# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import model_selection as ms
pd.set_option("display.max_rows",15)
# %matplotlib inline

# %%
data_path = "D:/AI/Jinoh Kim/new_one_class_svm/dataset/IDS_2017/Friday_full_3.csv"
intrusion = pd.read_csv(data_path)

# %%
intrusion.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0         56108               3268          6       112740690
# 1         42144                389          6       112740560
# 2             0                  0          0       113757377
# 3         63210               5355         17          100126
# 4             0                  0          0           54760
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0                  32                       16                         6448
# 1                  32                       16                         6448
# 2                 545                        0                            0
# 3                  22                        0                          616
# 4                   4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                        1152.0                     403
# 1                        5056.0                     403
# 2                           0.0                       0
# 3                           0.0                      28
# 4                           0.0                       0
#
#     Fwd Packet Length Min   ...     min_seg_size_forward   Active Mean  \
# 0                       0   ...                       32  3.594286e+02
# 1                       0   ...                       32  3.202857e+02
# 2                       0   ...                        0  9.361829e+06
# 3                      28   ...                       32  0.000000e+00
# 4                       0   ...                        0  0.000000e+00
#
#      Active Std   Active Max   Active Min   Idle Mean      Idle Std  \
# 0  1.199802e+01        380.0        343.0  16100000.0  4.988048e+05
# 1  1.574499e+01        330.0        285.0  16100000.0  4.987937e+05
# 2  7.324646e+06   18900000.0         19.0  12200000.0  6.935824e+06
# 3  0.000000e+00          0.0          0.0         0.0  0.000000e+00
# 4  0.000000e+00          0.0          0.0         0.0  0.000000e+00
#
#      Idle Max    Idle Min   label
# 0  16400000.0  15400000.0  BENIGN
# 1  16400000.0  15400000.0  BENIGN
# 2  20800000.0   5504997.0  BENIGN
# 3         0.0         0.0  BENIGN
# 4         0.0         0.0  BENIGN
#
# [5 rows x 81 columns]

# %%
no_of_lines = 702747 #train
#train_size = int(no_of_lines * 0.01)
train_size = no_of_lines

# %%
class dataset:
    col_names = ['Source Port','Destination Port','Protocol','Flow Duration','Total Fwd Packets','Total Backward Packets',
                'Total Length of Fwd Packets','Total Length of Bwd Packets','Fwd Packet Length Max','Fwd Packet Length Min','Fwd Packet Length Mean','Fwd Packet Length Std','Bwd Packet Length Max',
                'Bwd Packet Length Min','Bwd Packet Length Mean','Bwd Packet Length Std','Flow Bytes/s','Flow Packets/s','Flow IAT Mean','Flow IAT Std','Flow IAT Max','Flow IAT Min','Fwd IAT Total','Fwd IAT Mean',
                'Fwd IAT Std','Fwd IAT Max','Fwd IAT Min','Bwd IAT Total','Bwd IAT Mean','Bwd IAT Std','Bwd IAT Max','Bwd IAT Min','Fwd PSH Flags','Bwd PSH Flags','Fwd URG Flags','Bwd URG Flags','Fwd Header Length','Bwd Header Length','Fwd Packets/s','Bwd Packets/s','Min Packet Length','Max Packet Length','Packet length Mean',
                'Packet Length Std','Packet Length Variance','FIN Flag Count','SYN Flag Count','RST Flag Count','PSH Flag Count','ACK Flag Count','URG Flag Count','CWE Flag Count','ECE Flag Count','Down/Up Ratio','Average Packet Size','Avg Fwd Segment Size','Avg Bwd Segment Size','Fwd Header Length.1','Fwd Avg Bytes/Bulk','Fwd Avg Packets/Bulk',
                'Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd Avg Packets/Bulk','Bwd Avg Bulk Rate','Subflow Fwd Packets','SubFlow Fwd Bytes','SubFlow Bwd Packets','SubFlow Bwd Bytes','init_Win_bytes_forward','init_Win_bytes_backward','act_data_pkt_fwd','min_seg_size_forward','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','Label']

    sample_data = pd.read_csv("D:/AI/Jinoh Kim/new_one_class_svm/dataset/IDS_2017/Friday_full_3.csv", header = 0,names = col_names, nrows = train_size)
    sample_data.to_pickle('D:/AI/Jinoh Kim/new_one_class_svm/pkl/Friday_full.pkl')

# %%
dataset.test = pd.read_pickle('D:/AI/Jinoh Kim/new_one_class_svm/pkl/Friday_full.pkl')
dataset.label = dataset.test.Label.copy()

dataset.test
# Out:
#         Source Port  Destination Port  Protocol  Flow Duration  \
# 0             56108              3268         6      112740690
# 1             42144               389         6      112740560
# 2                 0                 0         0      113757377
# 3             63210              5355        17         100126
# 4                 0                 0         0          54760
# 5              1031                88         6            617
# 6                88              1031         6              8
# ...             ...               ...       ...            ...
# 702739        41922               443         6         144034
# 702740        41920               443         6         142876
# 702741        41926               443         6         196135
# 702742        41934               443         6         378424
# 702743        41932               443         6         161800
# 702744        41930               443         6         142864
# 702745        41928               443         6         186928
#
#         Total Fwd Packets  Total Backward Packets  \
# 0                      32                      16
# 1                      32                      16
# 2                     545                       0
# 3                      22                       0
# 4                       4                       0
# 5                       7                       4
# 6                       1                       1
# ...                   ...                     ...
# 702739                 48                      56
# 702740                 48                      56
# 702741                 49                      57
# 702742                 49                      59
# 702743                 70                     103
# 702744                 50                      62
# 702745                 46                      57
#
#         Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                              6448                       1152.0
# 1                              6448                       5056.0
# 2                                 0                          0.0
# 3                               616                          0.0
# 4                                 0                          0.0
# 5                               484                        414.0
# 6                                 6                          6.0
# ...                             ...                          ...
# 702739                         1313                     113081.0
# 702740                         1319                     102959.0
# 702741                         1331                     105841.0
# 702742                         1325                     104393.0
# 702743                         1427                     215903.0
# 702744                         1331                     110185.0
# 702745                         1319                     100049.0
#
#         Fwd Packet Length Max  Fwd Packet Length Min   ...    \
# 0                         403                      0   ...
# 1                         403                      0   ...
# 2                           0                      0   ...
# 3                          28                     28   ...
# 4                           0                      0   ...
# 5                         233                      0   ...
# 6                           6                      6   ...
# ...                       ...                    ...   ...
# 702739                    570                      0   ...
# 702740                    570                      0   ...
# 702741                    570                      0   ...
# 702742                    570                      0   ...
# 702743                    570                      0   ...
# 702744                    570                      0   ...
# 702745                    570                      0   ...
#
#         min_seg_size_forward   Active Mean    Active Std  Active Max  \
# 0                         32  3.594286e+02  1.199802e+01       380.0
# 1                         32  3.202857e+02  1.574499e+01       330.0
# 2                          0  9.361829e+06  7.324646e+06  18900000.0
# 3                         32  0.000000e+00  0.000000e+00         0.0
# 4                          0  0.000000e+00  0.000000e+00         0.0
# 5                         20  0.000000e+00  0.000000e+00         0.0
# 6                         20  0.000000e+00  0.000000e+00         0.0
# ...                      ...           ...           ...         ...
# 702739                    20  0.000000e+00  0.000000e+00         0.0
# 702740                    20  0.000000e+00  0.000000e+00         0.0
# 702741                    20  0.000000e+00  0.000000e+00         0.0
# 702742                    20  0.000000e+00  0.000000e+00         0.0
# 702743                    20  0.000000e+00  0.000000e+00         0.0
# 702744                    20  0.000000e+00  0.000000e+00         0.0
# 702745                    20  0.000000e+00  0.000000e+00         0.0
#
#         Active Min   Idle Mean      Idle Std    Idle Max    Idle Min   Label
# 0            343.0  16100000.0  4.988048e+05  16400000.0  15400000.0  BENIGN
# 1            285.0  16100000.0  4.987937e+05  16400000.0  15400000.0  BENIGN
# 2             19.0  12200000.0  6.935824e+06  20800000.0   5504997.0  BENIGN
# 3              0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 4              0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 5              0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 6              0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# ...            ...         ...           ...         ...         ...     ...
# 702739         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702740         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702741         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702742         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702743         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702744         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
# 702745         0.0         0.0  0.000000e+00         0.0         0.0  BENIGN
#
# [702746 rows x 81 columns]

# %%
dataset.label.unique()
# Out:
# array(['BENIGN', 'Bot', 'DDoS', 'PortScan'], dtype=object)

# %%
b1 = dataset.test.replace('BENIGN', 0)

# %%
b2 = b1.replace('Bot', 1)

# %%
b3 = b2.replace('DDoS', 1)

# %%
b4 = b3.replace('PortScan', 1)

# %%
b4_label = b4.Label.copy()

# %%
b4_label.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
b4_label.value_counts()
# Out:
# 0    500110
# 1    202636
# Name: Label, dtype: int64

# %%
category_variables = ["Protocol"]

for cv in category_variables:
    b4[cv] = b4[cv].astype("category")
    #a5[cv] = a5[cv].astype("category")
    
    print("Length of Categories for {} are {}".format(cv , len(b4[cv].cat.categories)))
    print("Categories for {} are {} \n".format(cv ,b4[cv].cat.categories))
# Out:
# Length of Categories for Protocol are 3
# Categories for Protocol are Int64Index([0, 6, 17], dtype='int64')

# %%
dummy_variables_2labels = category_variables
    
class preprocessing:
    train_labels = pd.get_dummies(b4, columns = dummy_variables_2labels, prefix=dummy_variables_2labels)
    #test_labels = pd.get_dummies(a5, columns = dummy_variables_2labels, prefix=dummy_variables_2labels)

# %%
preprocessing.train_labels.to_csv("D:/AI/Jinoh Kim/new_one_class_svm/csv/preprocessed_friday.csv")

# %%
preprocessing.train_labels
# Out:
#         Source Port  Destination Port  Flow Duration  Total Fwd Packets  \
# 0             56108              3268      112740690                 32
# 1             42144               389      112740560                 32
# 2                 0                 0      113757377                545
# 3             63210              5355         100126                 22
# 4                 0                 0          54760                  4
# 5              1031                88            617                  7
# 6                88              1031              8                  1
# ...             ...               ...            ...                ...
# 702739        41922               443         144034                 48
# 702740        41920               443         142876                 48
# 702741        41926               443         196135                 49
# 702742        41934               443         378424                 49
# 702743        41932               443         161800                 70
# 702744        41930               443         142864                 50
# 702745        41928               443         186928                 46
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# 0                           16                         6448
# 1                           16                         6448
# 2                            0                            0
# 3                            0                          616
# 4                            0                            0
# 5                            4                          484
# 6                            1                            6
# ...                        ...                          ...
# 702739                      56                         1313
# 702740                      56                         1319
# 702741                      57                         1331
# 702742                      59                         1325
# 702743                     103                         1427
# 702744                      62                         1331
# 702745                      57                         1319
#
#         Total Length of Bwd Packets  Fwd Packet Length Max  \
# 0                            1152.0                    403
# 1                            5056.0                    403
# 2                               0.0                      0
# 3                               0.0                     28
# 4                               0.0                      0
# 5                             414.0                    233
# 6                               6.0                      6
# ...                             ...                    ...
# 702739                     113081.0                    570
# 702740                     102959.0                    570
# 702741                     105841.0                    570
# 702742                     104393.0                    570
# 702743                     215903.0                    570
# 702744                     110185.0                    570
# 702745                     100049.0                    570
#
#         Fwd Packet Length Min  Fwd Packet Length Mean     ...       \
# 0                           0              201.500000     ...
# 1                           0              201.500000     ...
# 2                           0                0.000000     ...
# 3                          28               28.000000     ...
# 4                           0                0.000000     ...
# 5                           0               69.142857     ...
# 6                           6                6.000000     ...
# ...                       ...                     ...     ...
# 702739                      0               27.354167     ...
# 702740                      0               27.479167     ...
# 702741                      0               27.163265     ...
# 702742                      0               27.040816     ...
# 702743                      0               20.385714     ...
# 702744                      0               26.620000     ...
# 702745                      0               28.673913     ...
#
#         Active Max  Active Min   Idle Mean      Idle Std    Idle Max  \
# 0            380.0       343.0  16100000.0  4.988048e+05  16400000.0
# 1            330.0       285.0  16100000.0  4.987937e+05  16400000.0
# 2       18900000.0        19.0  12200000.0  6.935824e+06  20800000.0
# 3              0.0         0.0         0.0  0.000000e+00         0.0
# 4              0.0         0.0         0.0  0.000000e+00         0.0
# 5              0.0         0.0         0.0  0.000000e+00         0.0
# 6              0.0         0.0         0.0  0.000000e+00         0.0
# ...            ...         ...         ...           ...         ...
# 702739         0.0         0.0         0.0  0.000000e+00         0.0
# 702740         0.0         0.0         0.0  0.000000e+00         0.0
# 702741         0.0         0.0         0.0  0.000000e+00         0.0
# 702742         0.0         0.0         0.0  0.000000e+00         0.0
# 702743         0.0         0.0         0.0  0.000000e+00         0.0
# 702744         0.0         0.0         0.0  0.000000e+00         0.0
# 702745         0.0         0.0         0.0  0.000000e+00         0.0
#
#           Idle Min  Label  Protocol_0  Protocol_6  Protocol_17
# 0       15400000.0      0           0           1            0
# 1       15400000.0      0           0           1            0
# 2        5504997.0      0           1           0            0
# 3              0.0      0           0           0            1
# 4              0.0      0           1           0            0
# 5              0.0      0           0           1            0
# 6              0.0      0           0           1            0
# ...            ...    ...         ...         ...          ...
# 702739         0.0      0           0           1            0
# 702740         0.0      0           0           1            0
# 702741         0.0      0           0           1            0
# 702742         0.0      0           0           1            0
# 702743         0.0      0           0           1            0
# 702744         0.0      0           0           1            0
# 702745         0.0      0           0           1            0
#
# [702746 rows x 83 columns]
